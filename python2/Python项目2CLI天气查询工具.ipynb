# %%
import sys
import time
import jwt

private_key = """-----BEGIN PRIVATE KEY-----
MC4CAQAwBQYDK2VwBCIEIKBz8xkIFuDxyGCqyRJXYKIjTyl0vMVFRM8ak23QQwzk
-----END PRIVATE KEY-----

"""

payload = {
    'iat': int(time.time()) - 30,
    'exp': int(time.time()) + 900,
    'sub': '2M2BEP67PW'
}
headers = {
    'kid': 'TCGX3FA9WM'
}

try:
    # Generate JWT
    encoded_jwt = jwt.encode(payload, private_key, algorithm='EdDSA', headers=headers)
    print(f"JWT:  {encoded_jwt}")
except Exception as e:
    print(f"生成JWT失败: {e}", file=sys.stderr)
# Out:
# JWT:  eyJhbGciOiJFZERTQSIsImtpZCI6IlRDR1gzRkE5V00iLCJ0eXAiOiJKV1QifQ.eyJpYXQiOjE3NzA2MjEyNjIsImV4cCI6MTc3MDYyMjE5Miwic3ViIjoiMk0yQkVQNjdQVyJ9.HXozzuR7nMHBvyUDmjtsPfZItuRV_5_bwDULz_B-e1ZvjWUzVZD8cUZwZMXVwqR2JFtV00mMWy4vLxG-Bu3PBQ

# %%
api_host = 'https://jh3fc2274t.re.qweatherapi.com'
headers = {'Authorization': f'Bearer {encoded_jwt}'}
city_api = '/geo/v2/city/lookup'  #城市代码查询api
now_api = '/v7/weather/now'#实时天气api

#城市代码查询
city='深圳'
params = {'location': city}
url = f'{api_host}{city_api}'
response = requests.get(url,headers=headers,params=params)
city_id = response.json()['location'][0]['id']  # 获取城市代码
city_name = response.json()['location'][0]['name']  # 获取城市名称
country = response.json()['location'][0]['country']  # 获取国家名
#实时天气数据获取

url= f'{api_host}{now_api}'
headers = {'Authorization': f'Bearer {encoded_jwt}'}
params = {
    'location': city_id,  #城市代码
    'lang': 'zh',#语言
    'unit': 'm'
}
response = requests.get(url,headers=headers,params=params)
print(response)
print(response.text)
now_weather_data = response.json()
# 打印当前天气数据
print(f'城市: {country} {city_name}')
print(now_weather_data['now']['text']) 
print(f'温度: {now_weather_data["now"]["temp"]}°C')  
print(f'体感温度: {now_weather_data["now"]["feelsLike"]}°C')  
print(f'湿度: {now_weather_data["now"]["humidity"]}%')
print(f'风向: {now_weather_data["now"]["windDir"]}')  
print(f'风力等级: {now_weather_data["now"]["windScale"]}')  
print(f'风速: {now_weather_data["now"]["windSpeed"]} km/h') 
print(f'数据更新时间: {now_weather_data["updateTime"]}')
# Out:
# <Response [200]>
# {"code":"200","updateTime":"2026-02-09T15:13+08:00","fxLink":"https://www.qweather.com/weather/shenzhen-101280601.html","now":{"obsTime":"2026-02-09T15:10+08:00","temp":"16","feelsLike":"15","icon":"104","text":"阴","wind360":"46","windDir":"东北风","windScale":"1","windSpeed":"3","humidity":"57","precip":"0.0","pressure":"1013","vis":"21","cloud":"91","dew":"8"},"refer":{"sources":["QWeather"],"license":["QWeather Developers License"]}}
# 城市: 中国 深圳
# 阴
# 温度: 16°C
# 体感温度: 15°C
# 湿度: 57%
# 风向: 东北风
# 风力等级: 1
# 风速: 3 km/h
# 数据更新时间: 2026-02-09T15:13+08:00
